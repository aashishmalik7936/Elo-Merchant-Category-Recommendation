# %% [markdown]
# **FEEL FREE TO UPVOTE**  （＾ｖ＾）

# %%
import os
import numpy as np
import pandas as pd
import datetime
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import xgboost as xgb
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

from contextlib import contextmanager
from pandas.core.common import SettingWithCopyWarning
import warnings
warnings.filterwarnings('ignore')
np.random.seed(4590)

# %%
np.random.seed(4590)

# %%
print(os.listdir('../input'))
# Out:
# ['fork-of-continued', 'elo-blend', 'elo-dataset', 'continued', 'elo-merchant-category-recommendation']

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
train=pd.read_csv('../input/elo-merchant-category-recommendation/train.csv', parse_dates=["first_active_month"])
test=pd.read_csv('../input/elo-merchant-category-recommendation/test.csv', parse_dates=["first_active_month"])
df_hist_trans = pd.read_csv('../input/elo-merchant-category-recommendation/historical_transactions.csv')
df_new_merchant_trans = pd.read_csv('../input/elo-merchant-category-recommendation/new_merchant_transactions.csv')

# %%
def get_new_columns(name,aggs):
    return [name + '_' + k + '_' + agg for k in aggs.keys() for agg in aggs[k]]

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['category_2'].fillna(1.0,inplace=True)
    df['category_3'].fillna('A',inplace=True)
    df['merchant_id'].fillna('M_ID_00a6ca8a8a',inplace=True)

# %%
df_hist_trans=reduce_mem_usage(df_hist_trans)
df_new_merchant_trans=reduce_mem_usage(df_new_merchant_trans)

# %%
for df in [df_hist_trans,df_new_merchant_trans]:
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    df['year'] = df['purchase_date'].dt.year
    df['day']=df['purchase_date'].dt.day
    df['weekofyear'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    df['dayofweek'] = df['purchase_date'].dt.dayofweek
    df['weekend'] = (df.purchase_date.dt.weekday >=5).astype(int)
    df['hour'] = df['purchase_date'].dt.hour
    df['authorized_flag'] = df['authorized_flag'].map({'Y':1, 'N':0})
    df['category_1'] = df['category_1'].map({'Y':1, 'N':0})
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
    df['price']=df['purchase_amount']/df['installments']
    df['purchase_amount_quantiles']= pd.qcut(df['purchase_amount'], 5, labels=False)
    df['installments_quantiles']= pd.qcut(df['installments'], 5, labels=False)
gc.collect()

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size'],
aggs['installments_quantiles']=['var', 'mean', 'skew']
aggs['purchase_amount_quantiles']=['var', 'mean', 'skew']

for col in ['category_2','category_3']:
    df_hist_trans[col+'_mean'] = df_hist_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']    
    
new_columns = get_new_columns('hist',aggs)
df_hist_trans_group = df_hist_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['hist_purchase_date_diff'] = (df_hist_trans_group['hist_purchase_date_max'] - df_hist_trans_group['hist_purchase_date_min']).dt.days
df_hist_trans_group['hist_purchase_date_average'] = df_hist_trans_group['hist_purchase_date_diff']/df_hist_trans_group['hist_card_id_size']
df_hist_trans_group['hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['hist_purchase_date_max']).dt.days
df_hist_trans_group['hist_of_hist_purchase_date_average']=df_hist_trans_group['hist_purchase_date_diff']*df_hist_trans_group['hist_purchase_date_average']

df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group
gc.collect()

# %%
aggs = {}
for col in ['month','hour','weekofyear','dayofweek','year','subsector_id','merchant_id','merchant_category_id']:
    aggs[col] = ['nunique']

aggs['purchase_amount'] = ['sum','max','min','mean','var']
aggs['installments'] = ['sum','max','min','mean','var']
aggs['purchase_date'] = ['max','min']
aggs['month_lag'] = ['max','min','mean','var']
aggs['month_diff'] = ['mean']
aggs['authorized_flag'] = ['sum', 'mean']
aggs['weekend'] = ['sum', 'mean']
aggs['category_1'] = ['sum', 'mean']
aggs['card_id'] = ['size'],
aggs['installments_quantiles']=['var', 'mean', 'skew']
aggs['purchase_amount_quantiles']=['var', 'mean', 'skew']


for col in ['category_2','category_3']:
    df_new_merchant_trans[col+'_mean'] = df_new_merchant_trans.groupby([col])['purchase_amount'].transform('mean')
    aggs[col+'_mean'] = ['mean']

new_columns = get_new_columns('new_hist',aggs)
df_hist_trans_group = df_new_merchant_trans.groupby('card_id').agg(aggs)
df_hist_trans_group.columns = new_columns
df_hist_trans_group.reset_index(drop=False,inplace=True)
df_hist_trans_group['new_hist_purchase_date_diff'] = (df_hist_trans_group['new_hist_purchase_date_max'] - df_hist_trans_group['new_hist_purchase_date_min']).dt.days
df_hist_trans_group['new_hist_purchase_date_average'] = df_hist_trans_group['new_hist_purchase_date_diff']/df_hist_trans_group['new_hist_card_id_size']
df_hist_trans_group['new_hist_purchase_date_uptonow'] = (datetime.datetime.today() - df_hist_trans_group['new_hist_purchase_date_max']).dt.days
df_hist_trans_group['new_hist_of_new_hist_purchase_date_average']=df_hist_trans_group['new_hist_purchase_date_diff']*df_hist_trans_group['new_hist_purchase_date_average']

df_train = df_train.merge(df_hist_trans_group,on='card_id',how='left')
df_test = df_test.merge(df_hist_trans_group,on='card_id',how='left')
del df_hist_trans_group;gc.collect()

# %%
df_train['outliers'] = 0
df_train.loc[df_train['target'] < -30, 'outliers'] = 1
df_train['outliers'].value_counts()

# %%
for df in [df_train,df_test]:
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['dayofweek'] = df['first_active_month'].dt.dayofweek
    df['weekofyear'] = df['first_active_month'].dt.weekofyear
    df['month'] = df['first_active_month'].dt.month
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['hist_first_buy'] = (df['hist_purchase_date_min'] - df['first_active_month']).dt.days
    df['new_hist_first_buy'] = (df['new_hist_purchase_date_min'] - df['first_active_month']).dt.days
    for f in ['hist_purchase_date_max','hist_purchase_date_min','new_hist_purchase_date_max',\
                     'new_hist_purchase_date_min']:
        df[f] = df[f].astype(np.int64) * 1e-9
    df['card_id_total'] = df['new_hist_card_id_size']+df['hist_card_id_size']
    df['purchase_amount_total'] = df['new_hist_purchase_amount_sum']+df['hist_purchase_amount_sum']
    df['days_feature1'] = df['elapsed_time'] * df['feature_1']    
for f in ['feature_1','feature_2','feature_3']:
    order_label = df_train.groupby([f])['outliers'].mean()
    df_train[f] = df_train[f].map(order_label)
    df_test[f] = df_test[f].map(order_label)

# %%
df_train_columns = [c for c in df_train.columns if c not in ['card_id', 'first_active_month', 'target', 'outliers', 'hist_category_1_sum', 'new_hist_authorized_flag_mean', 'new_hist_merchant_id_nunique', 'new_hist_month_lag_min', 'new_hist_authorized_flag_sum', 'new_hist_month_nunique', 'new_hist_card_id_size', 'hist_dayofweek_nunique', 'new_hist_dayofweek_nunique', 'new_hist_weekofyear_nunique', 'new_hist_weekend_sum', 'hist_year_nunique', 'new_hist_hour_nunique', 'new_hist_year_nunique', 'new_hist_subsector_id_nunique', 'new_hist_month_wise_purchase_amount_mean_mean', 'hist_installments_min', 'new_hist_installments_max', 'hist_month_lag_min', 'new_hist_installments_min', 'feature_2', 'feature_3', 'hist_month_lag_max', 'new_hist_month_lag_max', 'new_hist_category_2_mean_mean', 'new_hist_installments_sum', 'new_hist_merchant_category_id_nunique', 'new_hist_weekend_mean', 'new_hist_installments_var', 'new_hist_category_3_mean_mean', 'new_hist_month_lag_var', 'dayofweek', 'feature_1', 'hist_installments_max', 'month', 'hist_hour_nunique', 'card_id_total', 'new_hist_month_diff_mean', 'hist_subsector_id_nunique', 'hist_card_id_size', 'hist_weekend_sum']]

# %%
def score_feature_selection(df_train=None, df_train_columns=None, target=None):
    params = {
            'gpu_id': 0, 
            #'n_gpus': 2, 
            'objective': 'reg:linear', 
            'eval_metric': 'rmse', 
            'silent': True, 
            'booster': 'gbtree', 
            'n_jobs': 4, 
            'n_estimators': 2500, 
            'tree_method': 'hist', 
            'grow_policy': 'lossguide', 
            'max_depth': 12, 
            'seed': 538, 
            'colsample_bylevel': 0.9, 
            'colsample_bytree': 0.8, 
            'gamma': 0.0001, 
            'learning_rate': 0.006150886706231842, 
            'max_bin': 128, 
            'max_leaves': 47, 
            'min_child_weight': 40, 
            'reg_alpha': 10.0, 
            'reg_lambda': 10.0, 
            'subsample': 0.95}

    
    folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=4590)
    oof = np.zeros(len(df_train))
    predictions = np.zeros(len(df_test))
    feature_importance_df = pd.DataFrame()

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'])):
        print("fold {}".format(fold_))
        X_train, y_train = df_train[df_train_columns].iloc[trn_idx], target.iloc[trn_idx]
        X_valid, y_valid = df_train[df_train_columns].iloc[val_idx], target.iloc[val_idx]        
        num_round = 10000
        model = xgb.XGBRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            verbose=100, eval_metric='rmse',
            early_stopping_rounds=500)
        oof[val_idx] = model.predict(df_train.iloc[val_idx][df_train_columns], ntree_limit=model.best_ntree_limit)
    
        #fold_importance_df = pd.DataFrame()
        #fold_importance_df["Feature"] = df_train_columns
        #fold_importance_df["importance"] = clf.feature_importance()
        #fold_importance_df["fold"] = fold_ + 1
        #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
        predictions += model.predict(df_test[df_train_columns], ntree_limit=model.best_ntree_limit) / folds.n_splits

    k=np.sqrt(mean_squared_error(oof, target))
    return k, predictions

# %%
print('no. of features:', len(df_train_columns))
gain_results, predictions = score_feature_selection(df_train=df_train, df_train_columns=df_train_columns, target=df_train['target'])
print('\t GAIN  : %.6f' % (gain_results))

best_sub = pd.DataFrame({"card_id":df_test["card_id"].values})
best_sub["target"] = predictions
# Out:
# no. of features: 73
# fold 0
# [08:40:55] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.95795
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.78384
# [200]	validation_0-rmse:3.72139
# [300]	validation_0-rmse:3.69632
# [400]	validation_0-rmse:3.68557
# [500]	validation_0-rmse:3.67918
# [600]	validation_0-rmse:3.67523
# [700]	validation_0-rmse:3.67241
# [800]	validation_0-rmse:3.67037
# [900]	validation_0-rmse:3.6684
# [1000]	validation_0-rmse:3.66711
# [1100]	validation_0-rmse:3.66614
# [1200]	validation_0-rmse:3.66508
# [1300]	validation_0-rmse:3.66483
# [1400]	validation_0-rmse:3.66458
# [1500]	validation_0-rmse:3.6646
# [1600]	validation_0-rmse:3.66479
# [1700]	validation_0-rmse:3.66471
# [1800]	validation_0-rmse:3.66474
# [1900]	validation_0-rmse:3.66477
# Stopping. Best iteration:
# [1431]	validation_0-rmse:3.66442
#
# fold 1
# [08:43:26] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.9621
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.78095
# [200]	validation_0-rmse:3.71326
# [300]	validation_0-rmse:3.68462
# [400]	validation_0-rmse:3.67101
# [500]	validation_0-rmse:3.66337
# [600]	validation_0-rmse:3.65694
# [700]	validation_0-rmse:3.65204
# [800]	validation_0-rmse:3.64848
# [900]	validation_0-rmse:3.64602
# [1000]	validation_0-rmse:3.64437
# [1100]	validation_0-rmse:3.64324
# [1200]	validation_0-rmse:3.64229
# [1300]	validation_0-rmse:3.64101
# [1400]	validation_0-rmse:3.64008
# [1500]	validation_0-rmse:3.63949
# [1600]	validation_0-rmse:3.63889
# [1700]	validation_0-rmse:3.63852
# [1800]	validation_0-rmse:3.63822
# [1900]	validation_0-rmse:3.6378
# [2000]	validation_0-rmse:3.63754
# [2100]	validation_0-rmse:3.63732
# [2200]	validation_0-rmse:3.63738
# [2300]	validation_0-rmse:3.6373
# [2400]	validation_0-rmse:3.63716
# [2499]	validation_0-rmse:3.63705
# fold 2
# [08:46:35] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.94565
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.76494
# [200]	validation_0-rmse:3.69821
# [300]	validation_0-rmse:3.67069
# [400]	validation_0-rmse:3.65831
# [500]	validation_0-rmse:3.65001
# [600]	validation_0-rmse:3.64401
# [700]	validation_0-rmse:3.64003
# [800]	validation_0-rmse:3.63733
# [900]	validation_0-rmse:3.63462
# [1000]	validation_0-rmse:3.63325
# [1100]	validation_0-rmse:3.63169
# [1200]	validation_0-rmse:3.63065
# [1300]	validation_0-rmse:3.62989
# [1400]	validation_0-rmse:3.62924
# [1500]	validation_0-rmse:3.62932
# [1600]	validation_0-rmse:3.62909
# [1700]	validation_0-rmse:3.62864
# [1800]	validation_0-rmse:3.62836
# [1900]	validation_0-rmse:3.6281
# [2000]	validation_0-rmse:3.62799
# [2100]	validation_0-rmse:3.62808
# [2200]	validation_0-rmse:3.62824
# [2300]	validation_0-rmse:3.62796
# [2400]	validation_0-rmse:3.6276
# [2499]	validation_0-rmse:3.62781
# fold 3
# [08:49:48] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.9513
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.77638
# [200]	validation_0-rmse:3.71501
# [300]	validation_0-rmse:3.69351
# [400]	validation_0-rmse:3.68342
# [500]	validation_0-rmse:3.67881
# [600]	validation_0-rmse:3.67534
# [700]	validation_0-rmse:3.67369
# [800]	validation_0-rmse:3.67219
# [900]	validation_0-rmse:3.6707
# [1000]	validation_0-rmse:3.66966
# [1100]	validation_0-rmse:3.66935
# [1200]	validation_0-rmse:3.66897
# [1300]	validation_0-rmse:3.6689
# [1400]	validation_0-rmse:3.66887
# [1500]	validation_0-rmse:3.66904
# [1600]	validation_0-rmse:3.669
# [1700]	validation_0-rmse:3.66903
# [1800]	validation_0-rmse:3.66918
# [1900]	validation_0-rmse:3.66892
# Stopping. Best iteration:
# [1416]	validation_0-rmse:3.66872
#
# fold 4
# [08:52:14] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.96919
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.78021
# [200]	validation_0-rmse:3.70792
# [300]	validation_0-rmse:3.67603
# [400]	validation_0-rmse:3.65998
# [500]	validation_0-rmse:3.65041
# [600]	validation_0-rmse:3.64398
# [700]	validation_0-rmse:3.63905
# [800]	validation_0-rmse:3.63523
# [900]	validation_0-rmse:3.63235
# [1000]	validation_0-rmse:3.63001
# [1100]	validation_0-rmse:3.62817
# [1200]	validation_0-rmse:3.62721
# [1300]	validation_0-rmse:3.62604
# [1400]	validation_0-rmse:3.62563
# [1500]	validation_0-rmse:3.6253
# [1600]	validation_0-rmse:3.62494
# [1700]	validation_0-rmse:3.62476
# [1800]	validation_0-rmse:3.62426
# [1900]	validation_0-rmse:3.62384
# [2000]	validation_0-rmse:3.62363
# [2100]	validation_0-rmse:3.62356
# [2200]	validation_0-rmse:3.62367
# [2300]	validation_0-rmse:3.62379
# [2400]	validation_0-rmse:3.62374
# [2499]	validation_0-rmse:3.62372
# fold 5
# [08:55:26] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.9546
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.78868
# [200]	validation_0-rmse:3.73286
# [300]	validation_0-rmse:3.7118
# [400]	validation_0-rmse:3.70241
# [500]	validation_0-rmse:3.69614
# [600]	validation_0-rmse:3.69127
# [700]	validation_0-rmse:3.68844
# [800]	validation_0-rmse:3.68597
# [900]	validation_0-rmse:3.68472
# [1000]	validation_0-rmse:3.68368
# [1100]	validation_0-rmse:3.68294
# [1200]	validation_0-rmse:3.68216
# [1300]	validation_0-rmse:3.68161
# [1400]	validation_0-rmse:3.6814
# [1500]	validation_0-rmse:3.68129
# [1600]	validation_0-rmse:3.6807
# [1700]	validation_0-rmse:3.68068
# [1800]	validation_0-rmse:3.68041
# [1900]	validation_0-rmse:3.68007
# [2000]	validation_0-rmse:3.67999
# [2100]	validation_0-rmse:3.67982
# [2200]	validation_0-rmse:3.67952
# [2300]	validation_0-rmse:3.67943
# [2400]	validation_0-rmse:3.67961
# [2499]	validation_0-rmse:3.67949
# fold 6
# [08:58:34] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.94802
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.76496
# [200]	validation_0-rmse:3.69991
# [300]	validation_0-rmse:3.67408
# [400]	validation_0-rmse:3.66166
# [500]	validation_0-rmse:3.65499
# [600]	validation_0-rmse:3.65001
# [700]	validation_0-rmse:3.646
# [800]	validation_0-rmse:3.64329
# [900]	validation_0-rmse:3.64134
# [1000]	validation_0-rmse:3.63988
# [1100]	validation_0-rmse:3.63829
# [1200]	validation_0-rmse:3.63755
# [1300]	validation_0-rmse:3.63656
# [1400]	validation_0-rmse:3.63599
# [1500]	validation_0-rmse:3.63583
# [1600]	validation_0-rmse:3.63528
# [1700]	validation_0-rmse:3.63509
# [1800]	validation_0-rmse:3.63484
# [1900]	validation_0-rmse:3.63453
# [2000]	validation_0-rmse:3.63456
# [2100]	validation_0-rmse:3.6346
# [2200]	validation_0-rmse:3.63492
# [2300]	validation_0-rmse:3.63484
# [2400]	validation_0-rmse:3.63473
# [2499]	validation_0-rmse:3.63444
# fold 7
# [09:01:43] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.94909
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.78854
# [200]	validation_0-rmse:3.73251
# [300]	validation_0-rmse:3.71057
# [400]	validation_0-rmse:3.70099
# [500]	validation_0-rmse:3.69523
# [600]	validation_0-rmse:3.69109
# [700]	validation_0-rmse:3.68757
# [800]	validation_0-rmse:3.68444
# [900]	validation_0-rmse:3.6821
# [1000]	validation_0-rmse:3.68038
# [1100]	validation_0-rmse:3.67855
# [1200]	validation_0-rmse:3.67731
# [1300]	validation_0-rmse:3.67686
# [1400]	validation_0-rmse:3.6759
# [1500]	validation_0-rmse:3.67524
# [1600]	validation_0-rmse:3.6747
# [1700]	validation_0-rmse:3.67417
# [1800]	validation_0-rmse:3.67383
# [1900]	validation_0-rmse:3.6735
# [2000]	validation_0-rmse:3.67343
# [2100]	validation_0-rmse:3.67334
# [2200]	validation_0-rmse:3.67315
# [2300]	validation_0-rmse:3.6732
# [2400]	validation_0-rmse:3.67332
# [2499]	validation_0-rmse:3.67319
# fold 8
# [09:04:52] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.92937
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.7474
# [200]	validation_0-rmse:3.68038
# [300]	validation_0-rmse:3.65187
# [400]	validation_0-rmse:3.63825
# [500]	validation_0-rmse:3.62981
# [600]	validation_0-rmse:3.62477
# [700]	validation_0-rmse:3.62096
# [800]	validation_0-rmse:3.61818
# [900]	validation_0-rmse:3.61557
# [1000]	validation_0-rmse:3.61417
# [1100]	validation_0-rmse:3.61286
# [1200]	validation_0-rmse:3.61152
# [1300]	validation_0-rmse:3.61079
# [1400]	validation_0-rmse:3.61016
# [1500]	validation_0-rmse:3.60996
# [1600]	validation_0-rmse:3.60967
# [1700]	validation_0-rmse:3.60944
# [1800]	validation_0-rmse:3.60912
# [1900]	validation_0-rmse:3.60887
# [2000]	validation_0-rmse:3.60914
# [2100]	validation_0-rmse:3.60899
# [2200]	validation_0-rmse:3.60887
# [2300]	validation_0-rmse:3.60918
# [2400]	validation_0-rmse:3.60908
# Stopping. Best iteration:
# [1953]	validation_0-rmse:3.60868
#
# fold 9
# [09:07:58] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:3.93206
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:3.76249
# [200]	validation_0-rmse:3.70491
# [300]	validation_0-rmse:3.68412
# [400]	validation_0-rmse:3.67399
# [500]	validation_0-rmse:3.66847
# [600]	validation_0-rmse:3.66445
# [700]	validation_0-rmse:3.66206
# [800]	validation_0-rmse:3.66017
# [900]	validation_0-rmse:3.65913
# [1000]	validation_0-rmse:3.65888
# [1100]	validation_0-rmse:3.65822
# [1200]	validation_0-rmse:3.6582
# [1300]	validation_0-rmse:3.65841
# [1400]	validation_0-rmse:3.65839
# [1500]	validation_0-rmse:3.65873
# Stopping. Best iteration:
# [1093]	validation_0-rmse:3.65815
#
# 	 GAIN  : 3.647511

# %%
train=df_train
test=df_test
df_train=df_train[df_train['outliers']==0]

# %%
def score_feature_selection(df_train=None, df_train_columns=None, target=None):
    params = {
            'gpu_id': 0, 
            #'n_gpus': 2, 
            'objective': 'reg:linear', 
            'eval_metric': 'rmse', 
            'silent': True, 
            'booster': 'gbtree', 
            'n_jobs': 4, 
            'n_estimators': 2500, 
            'tree_method': 'hist', 
            'grow_policy': 'lossguide', 
            'max_depth': 12, 
            'seed': 538, 
            'colsample_bylevel': 0.9, 
            'colsample_bytree': 0.8, 
            'gamma': 0.0001, 
            'learning_rate': 0.006150886706231842, 
            'max_bin': 128, 
            'max_leaves': 47, 
            'min_child_weight': 40, 
            'reg_alpha': 10.0, 
            'reg_lambda': 10.0, 
            'subsample': 0.95}

    
    folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=4590)
    oof = np.zeros(len(df_train))
    predictions = np.zeros(len(df_test))
    feature_importance_df = pd.DataFrame()

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'])):
        print("fold {}".format(fold_))
        X_train, y_train = df_train[df_train_columns].iloc[trn_idx], target.iloc[trn_idx]
        X_valid, y_valid = df_train[df_train_columns].iloc[val_idx], target.iloc[val_idx]        
        num_round = 10000
        model = xgb.XGBRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            verbose=100, eval_metric='rmse',
            early_stopping_rounds=500)
        oof[val_idx] = model.predict(df_train.iloc[val_idx][df_train_columns], ntree_limit=model.best_ntree_limit)
    
        #fold_importance_df = pd.DataFrame()
        #fold_importance_df["Feature"] = df_train_columns
        #fold_importance_df["importance"] = clf.feature_importance()
        #fold_importance_df["fold"] = fold_ + 1
        #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
        predictions += model.predict(df_test[df_train_columns], ntree_limit=model.best_ntree_limit) / folds.n_splits

    k=np.sqrt(mean_squared_error(oof, target))
    return k, predictions

# %%
print('no. of features:', len(df_train_columns))
gain_results, predictions = score_feature_selection(df_train=df_train, df_train_columns=df_train_columns, target=df_train['target'])
print('\t GAIN  : %.6f' % (gain_results))

model_without_outlier = pd.DataFrame({"card_id":df_test["card_id"].values})
model_without_outlier["target"] = predictions
# Out:
# no. of features: 73
# fold 0
# [09:10:02] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.80878
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.67213
# [200]	validation_0-rmse:1.62227
# [300]	validation_0-rmse:1.60187
# [400]	validation_0-rmse:1.59174
# [500]	validation_0-rmse:1.58612
# [600]	validation_0-rmse:1.5824
# [700]	validation_0-rmse:1.57985
# [800]	validation_0-rmse:1.57803
# [900]	validation_0-rmse:1.57683
# [1000]	validation_0-rmse:1.57588
# [1100]	validation_0-rmse:1.57516
# [1200]	validation_0-rmse:1.57452
# [1300]	validation_0-rmse:1.5741
# [1400]	validation_0-rmse:1.57371
# [1500]	validation_0-rmse:1.57337
# [1600]	validation_0-rmse:1.57309
# [1700]	validation_0-rmse:1.57288
# [1800]	validation_0-rmse:1.57275
# [1900]	validation_0-rmse:1.57257
# [2000]	validation_0-rmse:1.57242
# [2100]	validation_0-rmse:1.57222
# [2200]	validation_0-rmse:1.57216
# [2300]	validation_0-rmse:1.5721
# [2400]	validation_0-rmse:1.57202
# [2499]	validation_0-rmse:1.57193
# fold 1
# [09:13:39] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.8181
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.6812
# [200]	validation_0-rmse:1.63108
# [300]	validation_0-rmse:1.61028
# [400]	validation_0-rmse:1.60016
# [500]	validation_0-rmse:1.59443
# [600]	validation_0-rmse:1.59083
# [700]	validation_0-rmse:1.58821
# [800]	validation_0-rmse:1.58621
# [900]	validation_0-rmse:1.58475
# [1000]	validation_0-rmse:1.58366
# [1100]	validation_0-rmse:1.58285
# [1200]	validation_0-rmse:1.58225
# [1300]	validation_0-rmse:1.58175
# [1400]	validation_0-rmse:1.58138
# [1500]	validation_0-rmse:1.58118
# [1600]	validation_0-rmse:1.58102
# [1700]	validation_0-rmse:1.58082
# [1800]	validation_0-rmse:1.58069
# [1900]	validation_0-rmse:1.58064
# [2000]	validation_0-rmse:1.58054
# [2100]	validation_0-rmse:1.58047
# [2200]	validation_0-rmse:1.58033
# [2300]	validation_0-rmse:1.58031
# [2400]	validation_0-rmse:1.58019
# [2499]	validation_0-rmse:1.58016
# fold 2
# [09:17:06] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.78179
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.64264
# [200]	validation_0-rmse:1.59165
# [300]	validation_0-rmse:1.57107
# [400]	validation_0-rmse:1.56113
# [500]	validation_0-rmse:1.55561
# [600]	validation_0-rmse:1.55192
# [700]	validation_0-rmse:1.5494
# [800]	validation_0-rmse:1.54766
# [900]	validation_0-rmse:1.5463
# [1000]	validation_0-rmse:1.54532
# [1100]	validation_0-rmse:1.54461
# [1200]	validation_0-rmse:1.54408
# [1300]	validation_0-rmse:1.54365
# [1400]	validation_0-rmse:1.54332
# [1500]	validation_0-rmse:1.54313
# [1600]	validation_0-rmse:1.54293
# [1700]	validation_0-rmse:1.54273
# [1800]	validation_0-rmse:1.54269
# [1900]	validation_0-rmse:1.54261
# [2000]	validation_0-rmse:1.54249
# [2100]	validation_0-rmse:1.5424
# [2200]	validation_0-rmse:1.5423
# [2300]	validation_0-rmse:1.54222
# [2400]	validation_0-rmse:1.54218
# [2499]	validation_0-rmse:1.54207
# fold 3
# [09:20:39] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.79368
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.65773
# [200]	validation_0-rmse:1.60894
# [300]	validation_0-rmse:1.58941
# [400]	validation_0-rmse:1.58044
# [500]	validation_0-rmse:1.57565
# [600]	validation_0-rmse:1.57243
# [700]	validation_0-rmse:1.5701
# [800]	validation_0-rmse:1.56845
# [900]	validation_0-rmse:1.56724
# [1000]	validation_0-rmse:1.56627
# [1100]	validation_0-rmse:1.56566
# [1200]	validation_0-rmse:1.56514
# [1300]	validation_0-rmse:1.56475
# [1400]	validation_0-rmse:1.56445
# [1500]	validation_0-rmse:1.56419
# [1600]	validation_0-rmse:1.56398
# [1700]	validation_0-rmse:1.56376
# [1800]	validation_0-rmse:1.56367
# [1900]	validation_0-rmse:1.56353
# [2000]	validation_0-rmse:1.56342
# [2100]	validation_0-rmse:1.56332
# [2200]	validation_0-rmse:1.56319
# [2300]	validation_0-rmse:1.56308
# [2400]	validation_0-rmse:1.56304
# [2499]	validation_0-rmse:1.56291
# fold 4
# [09:24:13] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.83385
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.69385
# [200]	validation_0-rmse:1.64145
# [300]	validation_0-rmse:1.61964
# [400]	validation_0-rmse:1.60888
# [500]	validation_0-rmse:1.60254
# [600]	validation_0-rmse:1.59826
# [700]	validation_0-rmse:1.59527
# [800]	validation_0-rmse:1.59326
# [900]	validation_0-rmse:1.59172
# [1000]	validation_0-rmse:1.5906
# [1100]	validation_0-rmse:1.58979
# [1200]	validation_0-rmse:1.58923
# [1300]	validation_0-rmse:1.58882
# [1400]	validation_0-rmse:1.58844
# [1500]	validation_0-rmse:1.58817
# [1600]	validation_0-rmse:1.58801
# [1700]	validation_0-rmse:1.58773
# [1800]	validation_0-rmse:1.58768
# [1900]	validation_0-rmse:1.58753
# [2000]	validation_0-rmse:1.58752
# [2100]	validation_0-rmse:1.58745
# [2200]	validation_0-rmse:1.58739
# [2300]	validation_0-rmse:1.58728
# [2400]	validation_0-rmse:1.58722
# [2499]	validation_0-rmse:1.58714
# fold 5
# [09:27:46] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.80099
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.66161
# [200]	validation_0-rmse:1.61056
# [300]	validation_0-rmse:1.58927
# [400]	validation_0-rmse:1.57901
# [500]	validation_0-rmse:1.57322
# [600]	validation_0-rmse:1.56961
# [700]	validation_0-rmse:1.56723
# [800]	validation_0-rmse:1.56553
# [900]	validation_0-rmse:1.56426
# [1000]	validation_0-rmse:1.56331
# [1100]	validation_0-rmse:1.56252
# [1200]	validation_0-rmse:1.56201
# [1300]	validation_0-rmse:1.56158
# [1400]	validation_0-rmse:1.56121
# [1500]	validation_0-rmse:1.56095
# [1600]	validation_0-rmse:1.56069
# [1700]	validation_0-rmse:1.56054
# [1800]	validation_0-rmse:1.56041
# [1900]	validation_0-rmse:1.56023
# [2000]	validation_0-rmse:1.56016
# [2100]	validation_0-rmse:1.56007
# [2200]	validation_0-rmse:1.55992
# [2300]	validation_0-rmse:1.55987
# [2400]	validation_0-rmse:1.55974
# [2499]	validation_0-rmse:1.55969
# fold 6
# [09:31:18] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.78695
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.64465
# [200]	validation_0-rmse:1.59175
# [300]	validation_0-rmse:1.56997
# [400]	validation_0-rmse:1.55933
# [500]	validation_0-rmse:1.55328
# [600]	validation_0-rmse:1.54931
# [700]	validation_0-rmse:1.54648
# [800]	validation_0-rmse:1.5444
# [900]	validation_0-rmse:1.54289
# [1000]	validation_0-rmse:1.5418
# [1100]	validation_0-rmse:1.54102
# [1200]	validation_0-rmse:1.5405
# [1300]	validation_0-rmse:1.54009
# [1400]	validation_0-rmse:1.53975
# [1500]	validation_0-rmse:1.53956
# [1600]	validation_0-rmse:1.53933
# [1700]	validation_0-rmse:1.53916
# [1800]	validation_0-rmse:1.53898
# [1900]	validation_0-rmse:1.53885
# [2000]	validation_0-rmse:1.53878
# [2100]	validation_0-rmse:1.53873
# [2200]	validation_0-rmse:1.53868
# [2300]	validation_0-rmse:1.53859
# [2400]	validation_0-rmse:1.53857
# [2499]	validation_0-rmse:1.53861
# fold 7
# [09:34:52] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.80445
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.66695
# [200]	validation_0-rmse:1.61744
# [300]	validation_0-rmse:1.59749
# [400]	validation_0-rmse:1.58776
# [500]	validation_0-rmse:1.58224
# [600]	validation_0-rmse:1.57865
# [700]	validation_0-rmse:1.57611
# [800]	validation_0-rmse:1.57426
# [900]	validation_0-rmse:1.57275
# [1000]	validation_0-rmse:1.57166
# [1100]	validation_0-rmse:1.57081
# [1200]	validation_0-rmse:1.57006
# [1300]	validation_0-rmse:1.56951
# [1400]	validation_0-rmse:1.56918
# [1500]	validation_0-rmse:1.56885
# [1600]	validation_0-rmse:1.56853
# [1700]	validation_0-rmse:1.56831
# [1800]	validation_0-rmse:1.56808
# [1900]	validation_0-rmse:1.56794
# [2000]	validation_0-rmse:1.5678
# [2100]	validation_0-rmse:1.56767
# [2200]	validation_0-rmse:1.56754
# [2300]	validation_0-rmse:1.56743
# [2400]	validation_0-rmse:1.56736
# [2499]	validation_0-rmse:1.56724
# fold 8
# [09:38:24] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.76077
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.62096
# [200]	validation_0-rmse:1.57007
# [300]	validation_0-rmse:1.5494
# [400]	validation_0-rmse:1.53928
# [500]	validation_0-rmse:1.53342
# [600]	validation_0-rmse:1.52971
# [700]	validation_0-rmse:1.52717
# [800]	validation_0-rmse:1.5253
# [900]	validation_0-rmse:1.5239
# [1000]	validation_0-rmse:1.52294
# [1100]	validation_0-rmse:1.52217
# [1200]	validation_0-rmse:1.52157
# [1300]	validation_0-rmse:1.52109
# [1400]	validation_0-rmse:1.52077
# [1500]	validation_0-rmse:1.52045
# [1600]	validation_0-rmse:1.52013
# [1700]	validation_0-rmse:1.51999
# [1800]	validation_0-rmse:1.51993
# [1900]	validation_0-rmse:1.51983
# [2000]	validation_0-rmse:1.51967
# [2100]	validation_0-rmse:1.51957
# [2200]	validation_0-rmse:1.51949
# [2300]	validation_0-rmse:1.51936
# [2400]	validation_0-rmse:1.51929
# [2499]	validation_0-rmse:1.51925
# fold 9
# [09:41:56] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-rmse:1.76631
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# [100]	validation_0-rmse:1.62696
# [200]	validation_0-rmse:1.57585
# [300]	validation_0-rmse:1.55523
# [400]	validation_0-rmse:1.54528
# [500]	validation_0-rmse:1.53969
# [600]	validation_0-rmse:1.53617
# [700]	validation_0-rmse:1.53374
# [800]	validation_0-rmse:1.53192
# [900]	validation_0-rmse:1.53065
# [1000]	validation_0-rmse:1.52975
# [1100]	validation_0-rmse:1.52907
# [1200]	validation_0-rmse:1.52851
# [1300]	validation_0-rmse:1.52811
# [1400]	validation_0-rmse:1.52782
# [1500]	validation_0-rmse:1.52763
# [1600]	validation_0-rmse:1.52745
# [1700]	validation_0-rmse:1.52726
# [1800]	validation_0-rmse:1.52719
# [1900]	validation_0-rmse:1.52711
# [2000]	validation_0-rmse:1.52705
# [2100]	validation_0-rmse:1.52698
# [2200]	validation_0-rmse:1.52691
# [2300]	validation_0-rmse:1.5268
# [2400]	validation_0-rmse:1.52672
# [2499]	validation_0-rmse:1.52673
# 	 GAIN  : 1.555709

# %%
df_train = train
df_test = test

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import log_loss

# %%
def score_feature_selecti_2(df_train=None, df_train_columns=None, target=None):
    params = {
            'gpu_id': 0, 
            #'n_gpus': 2, 
            'objective': 'binary:logistic', 
            'eval_metric': 'logloss', 
            'silent': True, 
            'booster': 'gbtree', 
            'n_jobs': 4, 
            'n_estimators': 2500, 
            'tree_method': 'hist', 
            'grow_policy': 'lossguide', 
            'max_depth': 12, 
            'seed': 538, 
            'colsample_bylevel': 0.9, 
            'colsample_bytree': 0.8, 
            'gamma': 0.0001, 
            'learning_rate': 0.006150886706231842, 
            'max_bin': 128, 
            'max_leaves': 47, 
            'min_child_weight': 40, 
            'reg_alpha': 10.0, 
            'reg_lambda': 10.0, 
            'subsample': 0.95}

    
    folds = KFold(n_splits=10, shuffle=True, random_state=4590)
    oof = np.zeros(len(df_train))
    predictions = np.zeros(len(df_test))
    feature_importance_df = pd.DataFrame()

    for fold_, (trn_idx, val_idx) in enumerate(folds.split(df_train,df_train['outliers'])):
        print("fold {}".format(fold_))
        X_train, y_train = df_train[df_train_columns].iloc[trn_idx], target.iloc[trn_idx]
        X_valid, y_valid = df_train[df_train_columns].iloc[val_idx], target.iloc[val_idx]        
        num_round = 10000
        model = xgb.XGBRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            verbose=100, eval_metric='logloss',
            early_stopping_rounds=500)
        oof[val_idx] = model.predict(df_train.iloc[val_idx][df_train_columns], ntree_limit=model.best_ntree_limit)
    
        #fold_importance_df = pd.DataFrame()
        #fold_importance_df["Feature"] = df_train_columns
        #fold_importance_df["importance"] = clf.feature_importance()
        #fold_importance_df["fold"] = fold_ + 1
        #feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
        predictions += model.predict(df_test[df_train_columns], ntree_limit=model.best_ntree_limit) / folds.n_splits

    k=log_loss(target, oof)
    return k, predictions

# %%
print('no. of features:', len(df_train_columns))
gain_results, predictions = score_feature_selecti_2(df_train=df_train, df_train_columns=df_train_columns, target=df_train['outliers'])
print('\t GAIN  : %.6f' % (gain_results))

df_outlier_prob = pd.DataFrame({"card_id":df_test["card_id"].values})
df_outlier_prob["target"] = predictions
# Out:
# no. of features: 73
# fold 0
# [09:45:36] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687291
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.330256
# [200]	validation_0-logloss:0.184013
# [300]	validation_0-logloss:0.115438
# [400]	validation_0-logloss:0.081665
# [500]	validation_0-logloss:0.064783
# [600]	validation_0-logloss:0.056341
# [700]	validation_0-logloss:0.052098
# [800]	validation_0-logloss:0.049974
# [900]	validation_0-logloss:0.048927
# [1000]	validation_0-logloss:0.048379
# [1100]	validation_0-logloss:0.048076
# [1200]	validation_0-logloss:0.047903
# [1300]	validation_0-logloss:0.047815
# [1400]	validation_0-logloss:0.047763
# [1500]	validation_0-logloss:0.04775
# [1600]	validation_0-logloss:0.047733
# [1700]	validation_0-logloss:0.047717
# [1800]	validation_0-logloss:0.047729
# [1900]	validation_0-logloss:0.047745
# [2000]	validation_0-logloss:0.047765
# [2100]	validation_0-logloss:0.047781
# Stopping. Best iteration:
# [1649]	validation_0-logloss:0.04771
#
# fold 1
# [09:48:26] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687273
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329259
# [200]	validation_0-logloss:0.182357
# [300]	validation_0-logloss:0.113274
# [400]	validation_0-logloss:0.079134
# [500]	validation_0-logloss:0.061974
# [600]	validation_0-logloss:0.053277
# [700]	validation_0-logloss:0.048872
# [800]	validation_0-logloss:0.046647
# [900]	validation_0-logloss:0.045486
# [1000]	validation_0-logloss:0.04489
# [1100]	validation_0-logloss:0.044564
# [1200]	validation_0-logloss:0.0444
# [1300]	validation_0-logloss:0.044314
# [1400]	validation_0-logloss:0.044243
# [1500]	validation_0-logloss:0.044209
# [1600]	validation_0-logloss:0.04419
# [1700]	validation_0-logloss:0.044163
# [1800]	validation_0-logloss:0.044153
# [1900]	validation_0-logloss:0.044145
# [2000]	validation_0-logloss:0.044125
# [2100]	validation_0-logloss:0.044117
# [2200]	validation_0-logloss:0.044113
# [2300]	validation_0-logloss:0.044121
# [2400]	validation_0-logloss:0.044124
# [2499]	validation_0-logloss:0.044126
# fold 2
# [09:51:46] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687283
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.330147
# [200]	validation_0-logloss:0.183864
# [300]	validation_0-logloss:0.115234
# [400]	validation_0-logloss:0.08149
# [500]	validation_0-logloss:0.064601
# [600]	validation_0-logloss:0.056117
# [700]	validation_0-logloss:0.051922
# [800]	validation_0-logloss:0.049858
# [900]	validation_0-logloss:0.048813
# [1000]	validation_0-logloss:0.048244
# [1100]	validation_0-logloss:0.047963
# [1200]	validation_0-logloss:0.047821
# [1300]	validation_0-logloss:0.047762
# [1400]	validation_0-logloss:0.047728
# [1500]	validation_0-logloss:0.047725
# [1600]	validation_0-logloss:0.047713
# [1700]	validation_0-logloss:0.047709
# [1800]	validation_0-logloss:0.047715
# [1900]	validation_0-logloss:0.047744
# [2000]	validation_0-logloss:0.047745
# [2100]	validation_0-logloss:0.047763
# [2200]	validation_0-logloss:0.047768
# Stopping. Best iteration:
# [1719]	validation_0-logloss:0.047704
#
# fold 3
# [09:54:37] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687258
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.32796
# [200]	validation_0-logloss:0.180045
# [300]	validation_0-logloss:0.110189
# [400]	validation_0-logloss:0.075473
# [500]	validation_0-logloss:0.057878
# [600]	validation_0-logloss:0.048877
# [700]	validation_0-logloss:0.044257
# [800]	validation_0-logloss:0.041913
# [900]	validation_0-logloss:0.040683
# [1000]	validation_0-logloss:0.040009
# [1100]	validation_0-logloss:0.039617
# [1200]	validation_0-logloss:0.039388
# [1300]	validation_0-logloss:0.039257
# [1400]	validation_0-logloss:0.039178
# [1500]	validation_0-logloss:0.039139
# [1600]	validation_0-logloss:0.039118
# [1700]	validation_0-logloss:0.039099
# [1800]	validation_0-logloss:0.039094
# [1900]	validation_0-logloss:0.039078
# [2000]	validation_0-logloss:0.039074
# [2100]	validation_0-logloss:0.03907
# [2200]	validation_0-logloss:0.039061
# [2300]	validation_0-logloss:0.039058
# [2400]	validation_0-logloss:0.039057
# [2499]	validation_0-logloss:0.039061
# fold 4
# [09:57:53] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687272
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329141
# [200]	validation_0-logloss:0.182182
# [300]	validation_0-logloss:0.113193
# [400]	validation_0-logloss:0.079096
# [500]	validation_0-logloss:0.061956
# [600]	validation_0-logloss:0.053312
# [700]	validation_0-logloss:0.048962
# [800]	validation_0-logloss:0.046745
# [900]	validation_0-logloss:0.045575
# [1000]	validation_0-logloss:0.044949
# [1100]	validation_0-logloss:0.044606
# [1200]	validation_0-logloss:0.044423
# [1300]	validation_0-logloss:0.044285
# [1400]	validation_0-logloss:0.044196
# [1500]	validation_0-logloss:0.044128
# [1600]	validation_0-logloss:0.04409
# [1700]	validation_0-logloss:0.044055
# [1800]	validation_0-logloss:0.04403
# [1900]	validation_0-logloss:0.044006
# [2000]	validation_0-logloss:0.044003
# [2100]	validation_0-logloss:0.043996
# [2200]	validation_0-logloss:0.043984
# [2300]	validation_0-logloss:0.043981
# [2400]	validation_0-logloss:0.043983
# [2499]	validation_0-logloss:0.043986
# fold 5
# [10:01:18] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687271
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329036
# [200]	validation_0-logloss:0.18205
# [300]	validation_0-logloss:0.11297
# [400]	validation_0-logloss:0.078858
# [500]	validation_0-logloss:0.061754
# [600]	validation_0-logloss:0.053172
# [700]	validation_0-logloss:0.048833
# [800]	validation_0-logloss:0.046637
# [900]	validation_0-logloss:0.045509
# [1000]	validation_0-logloss:0.044913
# [1100]	validation_0-logloss:0.044585
# [1200]	validation_0-logloss:0.044413
# [1300]	validation_0-logloss:0.04432
# [1400]	validation_0-logloss:0.044264
# [1500]	validation_0-logloss:0.044217
# [1600]	validation_0-logloss:0.044185
# [1700]	validation_0-logloss:0.044175
# [1800]	validation_0-logloss:0.044165
# [1900]	validation_0-logloss:0.044158
# [2000]	validation_0-logloss:0.044145
# [2100]	validation_0-logloss:0.044144
# [2200]	validation_0-logloss:0.044146
# [2300]	validation_0-logloss:0.044141
# [2400]	validation_0-logloss:0.044149
# [2499]	validation_0-logloss:0.044147
# fold 6
# [10:04:40] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687279
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329564
# [200]	validation_0-logloss:0.182858
# [300]	validation_0-logloss:0.113982
# [400]	validation_0-logloss:0.079997
# [500]	validation_0-logloss:0.063008
# [600]	validation_0-logloss:0.05448
# [700]	validation_0-logloss:0.050193
# [800]	validation_0-logloss:0.048106
# [900]	validation_0-logloss:0.047053
# [1000]	validation_0-logloss:0.046536
# [1100]	validation_0-logloss:0.046228
# [1200]	validation_0-logloss:0.046062
# [1300]	validation_0-logloss:0.045945
# [1400]	validation_0-logloss:0.045881
# [1500]	validation_0-logloss:0.045833
# [1600]	validation_0-logloss:0.045808
# [1700]	validation_0-logloss:0.045797
# [1800]	validation_0-logloss:0.045788
# [1900]	validation_0-logloss:0.045792
# [2000]	validation_0-logloss:0.045794
# [2100]	validation_0-logloss:0.045797
# [2200]	validation_0-logloss:0.045799
# Stopping. Best iteration:
# [1777]	validation_0-logloss:0.045786
#
# fold 7
# [10:07:39] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687273
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329037
# [200]	validation_0-logloss:0.181994
# [300]	validation_0-logloss:0.112928
# [400]	validation_0-logloss:0.07883
# [500]	validation_0-logloss:0.061745
# [600]	validation_0-logloss:0.053146
# [700]	validation_0-logloss:0.048901
# [800]	validation_0-logloss:0.046769
# [900]	validation_0-logloss:0.045691
# [1000]	validation_0-logloss:0.045159
# [1100]	validation_0-logloss:0.044836
# [1200]	validation_0-logloss:0.044681
# [1300]	validation_0-logloss:0.044561
# [1400]	validation_0-logloss:0.044503
# [1500]	validation_0-logloss:0.044456
# [1600]	validation_0-logloss:0.044436
# [1700]	validation_0-logloss:0.044414
# [1800]	validation_0-logloss:0.044392
# [1900]	validation_0-logloss:0.04437
# [2000]	validation_0-logloss:0.044365
# [2100]	validation_0-logloss:0.044375
# [2200]	validation_0-logloss:0.044391
# [2300]	validation_0-logloss:0.044382
# [2400]	validation_0-logloss:0.044386
# Stopping. Best iteration:
# [1993]	validation_0-logloss:0.044363
#
# fold 8
# [10:11:00] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687283
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.329667
# [200]	validation_0-logloss:0.182947
# [300]	validation_0-logloss:0.113944
# [400]	validation_0-logloss:0.079683
# [500]	validation_0-logloss:0.062329
# [600]	validation_0-logloss:0.053485
# [700]	validation_0-logloss:0.048965
# [800]	validation_0-logloss:0.04665
# [900]	validation_0-logloss:0.045453
# [1000]	validation_0-logloss:0.04482
# [1100]	validation_0-logloss:0.044454
# [1200]	validation_0-logloss:0.044253
# [1300]	validation_0-logloss:0.044156
# [1400]	validation_0-logloss:0.044086
# [1500]	validation_0-logloss:0.044057
# [1600]	validation_0-logloss:0.044043
# [1700]	validation_0-logloss:0.044034
# [1800]	validation_0-logloss:0.044025
# [1900]	validation_0-logloss:0.044026
# [2000]	validation_0-logloss:0.044032
# [2100]	validation_0-logloss:0.044049
# [2200]	validation_0-logloss:0.044076
# [2300]	validation_0-logloss:0.044098
# Stopping. Best iteration:
# [1838]	validation_0-logloss:0.044023
#
# fold 9
# [10:14:01] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
# [0]	validation_0-logloss:0.687271
# Will train until validation_0-logloss hasn't improved in 500 rounds.
# [100]	validation_0-logloss:0.328989
# [200]	validation_0-logloss:0.181958
# [300]	validation_0-logloss:0.112795
# [400]	validation_0-logloss:0.078497
# [500]	validation_0-logloss:0.061107
# [600]	validation_0-logloss:0.05219
# [700]	validation_0-logloss:0.047621
# [800]	validation_0-logloss:0.045321
# [900]	validation_0-logloss:0.044111
# [1000]	validation_0-logloss:0.043477
# [1100]	validation_0-logloss:0.043129
# [1200]	validation_0-logloss:0.042931
# [1300]	validation_0-logloss:0.04281
# [1400]	validation_0-logloss:0.042742
# [1500]	validation_0-logloss:0.042708
# [1600]	validation_0-logloss:0.04268
# [1700]	validation_0-logloss:0.042666
# [1800]	validation_0-logloss:0.042659
# [1900]	validation_0-logloss:0.042666
# [2000]	validation_0-logloss:0.042678
# [2100]	validation_0-logloss:0.042693
# [2200]	validation_0-logloss:0.042703
# Stopping. Best iteration:
# [1794]	validation_0-logloss:0.042657
#
# 	 GAIN  : 0.044352

# %%
outlier_id = df_outlier_prob[df_outlier_prob['target']>0.5]
outliers=outlier_id['card_id']

# %%
most_likely_liers = best_sub.merge(outlier_id,how='right')
most_likely_liers.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.080751
# 1  C_ID_b709037bc5 -1.010545
# 2  C_ID_f7cada36d3  0.452038
# 3  C_ID_6d8dba8475 -0.770577
# 4  C_ID_7f1041e8e1 -3.868524

# %%
# %%time
for card_id in most_likely_liers['card_id']:
    model_without_outlier.loc[model_without_outlier['card_id']==card_id,'target']\
    = most_likely_liers.loc[most_likely_liers['card_id']==card_id,'target'].values
# Out:
# CPU times: user 6min 20s, sys: 332 ms, total: 6min 21s
# Wall time: 6min 21s

# %%
model_without_outlier.to_csv("combining_submission_xgb.csv", index=False)
